# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei'] #设置字体，设置了字体后，负号会变成乱码
plt.rcParams['axes.unicode_minus'] = False #让负号的乱码正常显示

# %%
DateLabel = ['2016', '2017', '2018', '2019', '2020', '2021']
NationalDebt = [12.6, 13.5, 15, 16.4, 20.2, 22.5]
LocalDebt = [15.4, 16.5, 18.5, 21.3, 25.7, 30.3]
GrowthRate = [9.8, 7.1, 11.6, 12.7, 21.6, 15.1]

# %%
x = np.arange(6)
bar_width = 0.35

plt.bar(x, NationalDebt, bar_width, align='center', label='国债', alpha=0.5)
plt.bar(x+bar_width, LocalDebt, bar_width, align='center', label='地方债', alpha=0.5)
plt.plot(x+bar_width/2, GrowthRate, 'r', label='政府债增速')
plt.xticks(x+bar_width/2, DateLabel)
plt.ylabel('国债(万亿)\\增速(%)')
plt.title('图 7: 2016 年~ 2021 年中国政府债务结构与增速')
plt.legend(loc='lower right')
